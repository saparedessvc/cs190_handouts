# %% [markdown]
# [Chapter 1. The Python Programming Language](./Chapter%201.ipynb)

# %% [markdown]
# [Chapter 2. Variables, Statements, and Expressions](./Chapter%202.ipynb)

# %% [markdown]
# [Chapter 3. Python Modules and Debugging](./Chapter%203.ipynb)

# %% [markdown]
# [Chapter 4. Sequences](./Chapter%204.ipynb)

# %% [markdown]
# [Chapter 5. Iteration](./Chapter%205.ipynb)

# %% [markdown]
# [Chapter 6. Conditionals](./Chapter%206.ipynb)

# %% [markdown]
# [Chapter 7. Dictionaries](./Chapter%207.ipynb)

# %% [markdown]
# [Chapter 8. The NumPy Library](./Chapter%208.ipynb)

# %% [markdown]
# [Chapter 9. The pandas Library](./Chapter%209.ipynb)

# %% [markdown]
# [Chapter 9 continue. The pandas Library](./Chapter%209%20cont.ipynb)

# %% [markdown]
# [Chapter 10. pandas: Reading and Writing Data](./Chapter%2010.ipynb)

# %% [markdown]
# [Chapter 11. Data Visualization with matplotlib](./Chapter%2011.ipynb)

# %% [markdown]
# [Chapter 11 continue. Data Visualization with matplotlib](./Chapter%2011%20cont.ipynb)
